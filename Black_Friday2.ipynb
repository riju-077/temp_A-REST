# %% [markdown]
# ##Practice-1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/blackfriday.csv')

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200

# %%
df.sample(2)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 431836  1000482  P00323642      M  26-35          14             A
# 98499   1003292  P00296042      F  51-55           6             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 431836                          2               1                   8
# 98499                           3               0                   8
#
#         Product_Category_2  Product_Category_3  Purchase
# 431836                 NaN                 NaN      7768
# 98499                 13.0                16.0      4139

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.isnull().sum().sort_values(ascending=True)
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Purchase                           0
# Product_Category_2            173638
# Product_Category_3            383247
# dtype: int64

# %%
df[['Product_Category_2','Product_Category_3']].isnull().sum()
# Out:
# Product_Category_2    173638
# Product_Category_3    383247
# dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# M    414259
# F    135809
# Name: count, dtype: int64

# %%
df['Gender'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df[df['Gender']=='M']['City_Category'].value_counts()
# Out:
# City_Category
# B    173377
# C    128866
# A    112016
# Name: count, dtype: int64

# %%
df['City_Category'].value_counts().sort_values(ascending=True)
# Out:
# City_Category
# A    147720
# C    171175
# B    231173
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df[(df['Gender']=='M') & (df['Marital_Status']==0) & (df['City_Category']=='B')][['Purchase','Age']]
# Out:
#         Purchase    Age
# 97          3055  18-25
# 196         2832  26-35
# 197         8066  26-35
# 198        15812  26-35
# 199         6967  26-35
# ...          ...    ...
# 549978       140  26-35
# 550012        26   0-17
# 550020        36  18-25
# 550028       483  36-45
# 550031       131  36-45
#
# [102194 rows x 2 columns]

# %%
df[['Gender','Age','Occupation']].tail(2)
# Out:
#        Gender    Age  Occupation
# 550066      F    55+           1
# 550067      F  46-50           0
